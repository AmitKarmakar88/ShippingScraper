# %%
import wget
import os
url = 'http://www.klineglobalroro.com/schedules/1-1_europe_to_north_america_and_mexico_gulf_schedule.pdf'

fileName='1-1_europe_to_north_america_and_mexico_gulf_schedule.pdf'

if not os.path.exists(fileName):
    wget.download(url,fileName)
# Out:
# 100% [..............................................................................] 50245 / 50245

# %%
import urllib.request
urllib.request.urlretrieve(url, "filename.pdf")
# Out:
# ('filename.pdf', <http.client.HTTPMessage at 0x19f3e643250>)

# %%
import requests
response = requests.get(url)
with open('filename.pdf', 'wb') as f:
    print(response.content)
    f.write(response.content)
    f.close()
# Out:
# b'\xef\xbb\xbf<!doctype html>\n<html>\n<head>\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width">\n\n<title>&ldquo;K&rdquo; Line GLOBAL RORO SERVICE</title>\n\n<meta name="description" content="The web site of &ldquo;K&rdquo; Line Global RORO Service, a provider of Car Carrier (PCC) and RORO, High and Heavy / Break Bulk, and Auto Logistics.">\n<meta name="keywords" content="">\n<meta name="author" content="" />\n\n<!-- Google Tag Manager -->\n<script>\n(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);})(window,document,\'script\',\'dataLayer\',\'GTM-WJC7MVF\');\n</script>\n<!-- End Google Tag Manager -->\n\n\n<link href="common/css/common.css" rel="stylesheet" type="text/css" />\n<link href="common/css/reset.css" rel="stylesheet" type="text/css" />\n<link href="common/css/top.css" rel="stylesheet" type="text/css" />\n\n\n<script src="common/js/jquery.js" type="text/javascript"></script>\n<script src="common/js/jquery.easing.1.3.js" type="text/javascript"></script>\n\n<script src="common/js/org.js" type="text/javascript"></script>\n\n\n<!-------- jQuery Scrollify JS---------->\n<link href="common/css/scrollify.css" rel="stylesheet" type="text/css" />\n<script src="common/js/jquery.scrollify.min.js"></script>\n<script src="common/js/scrollify.bug.fix.js"></script>\n\n<!-- jQuery Scrollify only PC -->\n<script type="text/javascript">\n$(function(){  \nvar agent = navigator.userAgent;  \nif(agent.search(/iPhone/) != -1 || agent.search(/iPad/) != -1 || agent.search(/iPod/) != -1 ){  \n\t$.scrollify.disable();\n  }else{  \n\t$.scrollify({section:".box"});\n\t}  \n});\n</script>\n\n\n<!-------- TOP page Header animation ---------->\n<script>\n$(function() {\n  $(window).load(function() {\n    var fadeSpeed = 1000;\n    $(\'.top_head\').each(function(i) {\n      $(this).delay(500).animate({\n        \'opacity\': 1\n      }, fadeSpeed);\n    });\n  });\n});\n</script>\n\n\n<!-------- Contents parts ScrollAnimation ---------->\n<link href="https://cdn.rawgit.com/michalsnik/aos/2.1.1/dist/aos.css" rel="stylesheet">\n<code><script src="https://cdn.rawgit.com/michalsnik/aos/2.1.1/dist/aos.js"></script></code>\n\n<script>\nAOS.init();\n</script>\n\n\n<!-------- "NETWORK" BG animation ---------->\n<script>\njQuery(function($){\n\t$(window).on(\'scroll\', function(){\n\t\t$(\'.layer-01\').addClass(\'is-active\').delay(500).queue(function() {\n\t\t\t$(\'.layer-02\').addClass(\'is-active\').dequeue();\n\t\t});\n\t});\n});\n</script>\n\n\n<!-------- "NETWORK" Tab Change animation ---------->\n<link href="common/css/tabtab.css" rel="stylesheet" type="text/css" />\n<script src="common/js/velocity.min.js"></script>\n<script>\n$(function() {\n\t$(\'.tabs\').tabtab({\n\t\ttabMenu: \'.tabs-menu\',\n\t\ttabContent: \'.tabs-content\',   \n\t});\n});\n</script>\n<script src="common/js/tabtab.min.js"></script>\n\n\n<!-------- "NETWORK" Img Change ---------->\n<script type="text/javascript">\nfunction changeMapImage(imgPath) {\n\tdocument.getElementById(\'map\').src = imgPath;\n}\n</script>\n\n\n<!-------- "NEWS" contents area scroll ---------->\n<script src="common/js/jquery.nicescroll.min.js"></script>\n<script>\n$(document).ready(\n\tfunction() {\n\t\t$("#news_txt").niceScroll({cursorcolor:"#c60219"});\n\t}\n);\n</script>\n\n\n\n</head>\n\n<body id="index">\n\n<!-- Google Tag Manager (noscript) -->\n<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-WJC7MVF" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>\n<!-- End Google Tag Manager (noscript) -->\n\n\n<div class="wrap">\n\n    <!--------------------------------------------------------\n    \t\t\t\t\tSection Home\n    ---------------------------------------------------------->\n    \n  ...

# %%
from datetime import date
current_date = date.today().isoformat() 
current_date
# Out:
# '2022-02-14'
